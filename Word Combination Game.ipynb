# %%
print ('THIS IS A WORD GAME WHERE YOU PROVIDE POSSIBLE COMBINATIONS FROM THE WORD COMBINAION')

combination2 = ['mi', 'to',  'an',  'no',  'ma',  'it', 'ai', 'ti',  'at',  'na', 'am',  'ab',  'in',  'ta',  'bi',  'bo',  'mo',  'ba',  'om',  'on']
combination3 = ['Oat', 'cot', 'tam', 'bot', 'con', 'cat', 'ton', 'can', 'too', 'noo', 'boo', 'cam', 'act', 'cab', 'obi', 'tan' , 'ain' , 'tab' , 'aim' , 'tao' , 'ait' , 'tic' , 'tin' , 'cob' , 'oot' , 'tom' , 'oca' , 'not' , 'man' , 'bit' , 'moo' , 'bio' , 'mob' , 'moa' , 'inn' , 'bin' , 'ion' , 'moc' , 'mib' , 'bam' , 'mat' , 'ban' , 'bat' , 'mac' , 'mot' , 'nim' , 'mon' , 'boa' , 'ant' , 'nib' , 'nob' , 'nom' , 'nan' , 'nit' , 'ani' , 'nam' , 'coo' , 'nab']

combination4 = [ 'mano' , 'moat' , 'mono' , 'atom' , 'main' , 'moan' , 'mint' , 'bait' , 'mini' , 'mina' , 'mica' , 'bani' , 'moon' , 'noon' , 'moot' , 'tomb' , 'otic' , 'onto' , 'toon' , 'omit' , 'ambo' , 'obit' , 'obia' , 'tain' , 'amin' , 'nota' , 'nona' , 'noma' , 'taco' , 'anon' , 'anti' , 'naoi' , 'toom' , 'conn' , 'bint' , 'inia' , 'coat' , 'coma' , 'cain' , 'icon' , 'coin' , 'comb' , 'bota' , 'iamb' , 'boot' , 'coot' , 'boon' , 'boat' , 'coni' , 'boom' , 'cion' , 'cant' , 'bima' , 'inti' , 'into' , 'ciao' , 'Iota']

combination5 = ['tibia' , 'conin' , 'coati' , 'ontic' , 'toman' , 'combo' , 'canto' , 'tonic' , 'onion' , 'octan' , 'manic' , 'macon' , 'ionic' , 'nimbi' , 'inion' , 'niton' , 'imino' , 'taboo' , 'iambi' , 'cotan' , 'coomb' , 'conto' , 'nomoi' , 'matin' , 'ancon' , 'antic' , 'amici' , 'biont' , 'binit' , 'bacon' , 'biota' , 'amino' , 'amnic' , 'cabin' , 'anion' , 'ambit' , 'canon' , 'aboon' , 'acini' , 'baton' , 'actin' , 'animi' , 'Banco']

combination6 = ['intima' , 'miotic' , 'minion' , 'manioc' , 'mantic' , 'manito' , 'incant' , 'bionic' , 'canton' , 'camion' , 'combat' , 'cation' , 'bonito' , 'bonaci' , 'biotin' , 'biotic' , 'iambic' , 'bonita' , 'cannot' , 'atonic' , 'niobic' , 'action' , 'nomina' , 'obtain' , 'amnion' , 'tannic' , 'aminic' , 'noncom' , 'oomiac' , 'notion' , 'anoint' , 'tinman' , 'atomic', 'motion' , 'nation' , 'niacin' , 'intomb' , 'anomic' , 'Tombac']

combination7 = ['comitia' , 'abiotic' , 'amotion' , 'anionic' , 'biontic' , 'nicotin' , 'actinon' , 'coition' , 'botanic' , 'minicab' , 'contain']

combination8 = ['amniotic', 'amnionic', 'bionomic', 'mannitic', 'inaction', 'ambition', 'conation', 'monition']

score = 0
level = input ('Select the level with by selecting a, b, c or d \n(a) easy \n(b) hard \n(c) professional \n(d) Legend' )
if (level.lower() == 'a'):

    i = False
    count = 0 
    total = 5
    attempt = 0
    life = 5
    print ('PROVIDE 2 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 5 or i == False): 
        easy_combination2 = input ('Enter a correct 2 LETTER word in lower case')        
        if easy_combination2 in combination2: 
            combination2.remove(easy_combination2)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 5- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 5 
                i = True
    print('NEXT ROUND')        
    i = False
    count = 0
    total = 5
    attempt = 0
    life = 5
    print ('PROVIDE 3 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 5) or i == False:
        easy_combination3 = input ('Enter a correct 3 LETTER word in lower case')
        if easy_combination3 in combination3: 
            combination3.remove(easy_combination3)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 5- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 5 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 4
    attempt = 0
    life = 5
    print ('PROVIDE 4 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 4) or i == False:
        easy_combination4 = input ('Enter a correct 4 LETTER word in lower case')
        if easy_combination4 in combination4: 
            combination4.remove(easy_combination4)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 4- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 4 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 2
    attempt = 0
    life = 5
    print ('PROVIDE 5 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 2) or i == False:
        easy_combination5 = input ('Enter a correct 5 LETTER word in lower case')
        if easy_combination5 in combination5: 
            combination5.remove(easy_combination5)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 2- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 2 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 1
    attempt = 0
    life = 5
    print ('PROVIDE 6 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 1) or i == False:
        easy_combination6 = input ('Enter a correct 6 LETTER word in lower case')
        if easy_combination6 in combination6: 
            combination6.remove(easy_combination6)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 1- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 1 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 1
    attempt = 0
    life = 5
    print ('PROVIDE 7 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 1) or i == False:
        easy_combination7 = input ('Enter a correct 7 LETTER word in lower case')
        if easy_combination7 in combination7: 
            combination7.remove(easy_combination7)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 1- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 1 
                i = True
    print('NEXT ROUND') 
    
    i = False
    count = 0
    total = 1
    attempt = 0
    life = 5
    print ('PROVIDE 8 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 1) or i == False:
        easy_combination8 = input ('Enter a correct 8 LETTER word in lower case')
        if easy_combination8 in combination8: 
            combination8.remove(easy_combination8)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 1- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 1 
                i = True
    print('GAME OVER') 
            
            
            
            
            
            
if (level.lower() == 'b'):

    i = False
    count = 0
    total = 6
    attempt = 0
    life = 5
    print ('PROVIDE 2 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 6) or i == False: 
        easy_combination2 = input ('Enter a correct 2 LETTER word in lower case')
        if easy_combination2 in combination2: 
            combination2.remove(easy_combination2)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 6- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 6 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 6
    attempt = 0
    life = 5
    print ('PROVIDE 3 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 6) or i == False:
        easy_combination3 = input ('Enter a correct 3 LETTER word in lower case')
        if easy_combination3 in combination3: 
            combination3.remove(easy_combination3)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 6- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 6 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 6
    attempt = 0
    life = 5
    print ('PROVIDE 4 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 6) or i == False:
        easy_combination4 = input ('Enter a correct 4 LETTER word in lower case')
        if easy_combination4 in combination4: 
            combination4.remove(easy_combination4)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 6- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 6 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 3
    attempt = 0
    life = 5
    print ('PROVIDE 5 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 3) or i == False:
        easy_combination5 = input ('Enter a correct 5 LETTER word in lower case')
        if easy_combination5 in combination5: 
            combination5.remove(easy_combination5)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 3- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 3 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 2
    attempt = 0
    life = 5
    print ('PROVIDE 6 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 2) or i == False:
        easy_combination6 = input ('Enter a correct 6 LETTER word in lower case')
        if easy_combination6 in combination6: 
            combination6.remove(easy_combination6)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 2- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 2 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 2
    attempt = 0
    life = 5
    print ('PROVIDE 7 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 2) or i == False:
        easy_combination7 = input ('Enter a correct 7 LETTER word in lower case')
        if easy_combination7 in combination7: 
            combination7.remove(easy_combination7)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 2- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 2 
                i = True
    print('NEXT ROUND') 
    
    i = False
    count = 0 
    total = 2
    attempt = 0
    life = 5
    print ('PROVIDE 8 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 2) or i == False:
        easy_combination8 = input ('Enter a correct 8 LETTER word in lower case')
        if easy_combination8 in combination8: 
            combination8.remove(easy_combination8)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 2- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 2 
                i = True
    print('GAME OVER') 
            


            
            
            
            
            
if (level.lower() == 'c'):

    i = False
    count = 0
    total = 9
    attempt = 0
    life = 5
    print ('PROVIDE 2 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 9) or i == False: 
        easy_combination2 = input ('Enter a correct 2 LETTER word in lower case')
        if easy_combination2 in combination2: 
            combination2.remove(easy_combination2)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 9- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 9 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 8
    attempt = 0
    life = 5
    print ('PROVIDE 3 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 8) or i == False:
        easy_combination3 = input ('Enter a correct 3 LETTER word in lower case')
        if easy_combination3 in combination3: 
            combination3.remove(easy_combination3)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 8- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 8 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 7
    attempt = 0
    life = 5
    print ('PROVIDE 4 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 7) or i == False:
        easy_combination4 = input ('Enter a correct 4 LETTER word in lower case')
        if easy_combination4 in combination4: 
            combination4.remove(easy_combination4)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 7- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 7 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 6
    attempt = 0
    life = 5
    print ('PROVIDE 5 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 6) or i == False:
        easy_combination5 = input ('Enter a correct 5 LETTER word in lower case')
        if easy_combination5 in combination5: 
            combination5.remove(easy_combination5)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 6- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 6 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 5
    attempt = 0
    life = 5
    print ('PROVIDE 6 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 5) or i == False:
        easy_combination6 = input ('Enter a correct 6 LETTER word in lower case')
        if easy_combination6 in combination6: 
            combination6.remove(easy_combination6)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 5- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 5 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 4
    attempt = 0
    life = 5
    print ('PROVIDE 7 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 4) or i == False:
        easy_combination7 = input ('Enter a correct 7 LETTER word in lower case')
        if easy_combination7 in combination7: 
            combination7.remove(easy_combination7)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 4- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 4 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0   
    total = 3
    attempt = 0
    life = 5
    print ('PROVIDE 8 LETTER WORDS FROM THE WORD COMBINATION')
    while (count < 3) or i == False:
        easy_combination8 = input ('Enter a correct 8 LETTER word in lower case')
        if easy_combination8 in combination8: 
            combination8.remove(easy_combination8)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 3- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 3 
                i = True
    print('GAME OVER') 
            

            
            
            
            
            
            
            
if (level.lower() == 'd'):

    i = False
    count = 0
    total = 20
    attempt = 0
    life = 5
    print ('PROVIDE ALL POSSIBLE TWO LETTER WORDS FROM THE WORD COMBINATION')
    print ('HINT: THERE ARE 20 POSSIBLE WORDS ')
    while (count < 20) or i == False: 
        easy_combination2 = input ('Enter a correct 2 LETTER word in lower case')
        if easy_combination2 in combination2: 
            combination2.remove(easy_combination2)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 20- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 20 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 58
    attempt = 0
    life = 5
    print ('PROVIDE ALL POSSIBLE THREE LETTER WORDS FROM THE WORD COMBINATION')
    print ('HINT: THERE ARE 58 POSSIBLE WORDS ')
    while (count < 58) or i == False:
        easy_combination3 = input ('Enter a correct 3 LETTER word in lower case')
        if easy_combination3 in combination3: 
            combination3.remove(easy_combination3)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 58- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 58 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 57
    attempt = 0
    life = 5
    print ('PROVIDE ALL POSSIBLE FOUR LETTER WORDS FROM THE WORD COMBINATION')
    print ('HINT: THERE ARE 57 POSSIBLE WORDS ')
    while (count < 57) or i == False:
        easy_combination4 = input ('Enter a correct 4 LETTER word in lower case')
        if easy_combination4 in combination4: 
            combination4.remove(easy_combination4)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 57- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 57 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 43
    attempt = 0
    life = 5
    print ('PROVIDE ALL POSSIBLE FIVE LETTER WORDS FROM THE WORD COMBINATION')
    print ('HINT: THERE ARE 43 POSSIBLE WORDS ')
    while (count < 43) or i == False:
        easy_combination5 = input ('Enter a correct 5 LETTER word in lower case')
        if easy_combination5 in combination5: 
            combination5.remove(easy_combination5)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 43- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 43 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 39
    attempt = 0
    life = 5
    print ('PROVIDE ALL POSSIBLE SIX LETTER WORDS FROM THE WORD COMBINATION')
    print ('HINT: THERE ARE 39 POSSIBLE WORDS ')
    while (count < 39) or i == False:
        easy_combination6 = input ('Enter a correct 6 LETTER word in lower case')
        if easy_combination6 in combination6: 
            combination6.remove(easy_combination6)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 39- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 39 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0
    total = 11
    attempt = 0
    life = 5
    print ('PROVIDE ALL POSSIBLE SEVEN LETTER WORDS FROM THE WORD COMBINATION')
    print ('HINT: THERE ARE 11 POSSIBLE WORDS ')
    while (count < 11) or i == False:
        easy_combination7 = input ('Enter a correct 7 LETTER word in lower case')
        if easy_combination7 in combination7: 
            combination7.remove(easy_combination7)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 11- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 11 
                i = True
    print('NEXT ROUND') 
            
    i = False
    count = 0 
    total = 8
    attempt = 0
    life = 5
    print ('PROVIDE ALL POSSIBLE EIGHT LETTER WORDS FROM THE WORD COMBINATION')
    print ('HINT: THERE ARE 8 POSSIBLE WORDS ')
    while (count < 8) or i == False:
        easy_combination8 = input ('Enter a correct 8 LETTER word in lower case')
        if easy_combination8 in combination8: 
            combination8.remove(easy_combination8)
            score = score +1
            print ('CORRECT!')
            print ('Your score is', score)            
            count = count +1
            i = True
            total = 8- count
            print (total, 'more to go! and', life, 'attempts left')
        else:
            attempt = attempt +1 
            life = 5- attempt
            print ('WRONG!')
            i = False
            print (total, 'more combination to go! and', life, 'attempts left')
            if attempt == 5:
                count = 8 
                i = True
    print('GAME OVER') 
            
            
            
            
else:
    print ('Kindly relaunch the game and select game level by entering a, b, c or d')
